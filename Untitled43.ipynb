# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, r2_score

filepath = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-Coursera/laptop_pricing_dataset_mod2.csv'

df = pd.read_csv(filepath)
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 Manufacturer  Category  GPU  OS  CPU_core  \
# 0             0           0         Acer         4    2   1         5
# 1             1           1         Dell         3    1   1         3
# 2             2           2         Dell         3    1   1         7
# 3             3           3         Dell         4    2   1         5
# 4             4           4           HP         4    2   1         7
#
#    Screen_Size_inch  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_pounds  \
# 0              14.0       0.551724       8             256        3.52800
# 1              15.6       0.689655       4             256        4.85100
# 2              15.6       0.931034       8             256        4.85100
# 3              13.3       0.551724       8             128        2.69010
# 4              15.6       0.620690       8             256        4.21155
#
#    Price Price-binned  Screen-Full_HD  Screen-IPS_panel
# ...

# %%
df.drop(columns=['Unnamed: 0', 'Unnamed: 0.1'], inplace=True)
df.head()
# Out:
#   Manufacturer  Category  GPU  OS  CPU_core  Screen_Size_inch  CPU_frequency  \
# 0         Acer         4    2   1         5              14.0       0.551724
# 1         Dell         3    1   1         3              15.6       0.689655
# 2         Dell         3    1   1         7              15.6       0.931034
# 3         Dell         4    2   1         5              13.3       0.551724
# 4           HP         4    2   1         7              15.6       0.620690
#
#    RAM_GB  Storage_GB_SSD  Weight_pounds  Price Price-binned  Screen-Full_HD  \
# 0       8             256        3.52800    978          Low               0
# 1       4             256        4.85100    634          Low               1
# 2       8             256        4.85100    946          Low               1
# 3       8             128        2.69010   1244          Low               0
# 4       8             256        4.21155    837          Low               1
#
#    Screen-IPS_panel
# ...

# %%
y_data = df['Price']
x_data = df.drop('Price', axis=1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.1, random_state=0)

# %%
# Step 1: Create and train the model
lre = LinearRegression()
lre.fit(x_train[['CPU_frequency']], y_train)

# Step 2: Print R² for test and train
print("R² on Test data:", lre.score(x_test[['CPU_frequency']], y_test))
print("R² on Train data:", lre.score(x_train[['CPU_frequency']], y_train))
# Out:
# R² on Test data: -0.09730358788786875
# R² on Train data: 0.14724238605458895

# %% [markdown]
# Why is this happening?
# CPU_frequency alone ❌ is NOT enough to predict laptop price
# Because laptop price depends on many things like:
#
# RAM
# Storage
# GPU
# Brand
# Screen size etc.
#
# Using just one feature (CPU_frequency) makes it a weak model

# %% [markdown]
# Run a 4-fold cross validation on the model and print the mean value of R^2 score along with its standard deviation.

# %%
Rcross = cross_val_score(lre, x_data[['CPU_frequency']], y_data, cv=4)
print("The mean of the folds are", Rcross.mean(), "and the standard deviation is", Rcross.std())
# Out:
# The mean of the folds are -0.16109232388595113 and the standard deviation is 0.384957978666471

# %%
# ============================================
# IMPORTS
# ============================================
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, r2_score

# ============================================
# LOAD DATA
# ============================================
filepath = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-Coursera/laptop_pricing_dataset_mod2.csv'
df = pd.read_csv(filepath)

# ============================================
# DROP UNNECESSARY COLUMNS
# ============================================
df.drop(columns=['Unnamed: 0', 'Unnamed: 0.1'], inplace=True)

# ============================================
# SPLIT INTO X AND Y
# ============================================
y_data = df['Price']
x_data = df.drop('Price', axis=1)

# ============================================
# TASK 1 - LINEAR REGRESSION + CROSS VALIDATION
# ============================================
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.1, random_state=0)

lre = LinearRegression()
lre.fit(x_train[['CPU_frequency']], y_train)

print("R² on Test data:", lre.score(x_test[['CPU_frequency']], y_test))
print("R² on Train data:", lre.score(x_train[['CPU_frequency']], y_train))

# 4-Fold Cross Validation
Rcross = cross_val_score(lre, x_data[['CPU_frequency']], y_data, cv=4)
print("Mean R²:", Rcross.mean())
print("Standard Deviation:", Rcross.std())

# ============================================
# TASK 2 - OVERFITTING + GRID SEARCH
# ============================================
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.5, random_state=0)

parameters = [{'alpha': [0.001, 0.01, 0.1, 1, 10, 100, 1000, 10000]}]
RR = Ridge()
Grid1 = GridSearchCV(RR, parameters, cv=4)

Grid1.fit(x_train[['CPU_frequency', 'RAM_GB', 'Storage_GB_SSD', 'CPU_core', 'OS', 'GPU', 'Category']], y_train)

BestRR = Grid1.best_estimator_
print("Best Alpha:", Grid1.best_params_)
print("R² Score:", BestRR.score(x_test[['CPU_frequency', 'RAM_GB', 'Storage_GB_SSD', 'CPU_core', 'OS', 'GPU', 'Category']], y_test))
# Out:
# R² on Test data: -0.09730358788786875
# R² on Train data: 0.14724238605458895
# Mean R²: -0.16109232388595113
# Standard Deviation: 0.384957978666471
# Best Alpha: {'alpha': 10}
# R² Score: 0.300990504869182
