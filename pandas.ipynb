# %%
import pandas as pd
# Create a Series from a list
data = [10, 20, 30, 40, 50]
s = pd.Series(data)
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
import pandas as pd
data=[10,20,30,40,50]
s=pd.Series(data)
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
x={"name":["rose","john","jane","mary"],"id":[1,2,3,4],"roll_no":[101,102,103,104]}
df=pd.DataFrame(x)
print(df)
# Out:
#    name  id  roll_no
# 0  rose   1      101
# 1  john   2      102
# 2  jane   3      103
# 3  mary   4      104

# %%
x=df[["name"]]
print(x)
# Out:
#    name
# 0  rose
# 1  john
# 2  jane
# 3  mary

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
x={"name":["rose","john","jane","mary"],"id":[1,2,3,4],"roll_no":[101,102,103,104]}
df=pd.DataFrame(x)
print(df)
print("accessing multiple columns which we want")
y=df[["name","roll_no"]]
print(y)
# Out:
#    name  id  roll_no
# 0  rose   1      101
# 1  john   2      102
# 2  jane   3      103
# 3  mary   4      104
# accessing multiple columns which we want
#    name  roll_no
# 0  rose      101
# 1  john      102
# 2  jane      103
# 3  mary      104
