# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#you will need to download the dataset;
# !wget 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/module_5_auto.csv' -O 'module_5_auto.csv'
# Out:
# --2026-03-02 17:05:00--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/module_5_auto.csv
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 198.23.119.245
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|198.23.119.245|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 37048 (36K) [text/csv]
# Saving to: ‘module_5_auto.csv’
#
# module_5_auto.csv   100%[===================>]  36.18K  --.-KB/s    in 0.03s
#
# 2026-03-02 17:05:00 (1.32 MB/s) - ‘module_5_auto.csv’ saved [37048/37048]

# %%
df = pd.read_csv("module_5_auto.csv", header=0)

# %%
filepath = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/module_5_auto.csv'
df = pd.read_csv(filepath, header=None)

# %%
df.head()
# Out:
#     0           1          2                  3            4           5   \
# 0  NaN  Unnamed: 0  symboling  normalized-losses         make  aspiration
# 1  0.0           0          3                122  alfa-romero         std
# 2  1.0           1          3                122  alfa-romero         std
# 3  2.0           2          1                122  alfa-romero         std
# 4  3.0           3          2                164         audi         std
#
#              6            7             8                9   ...  \
# 0  num-of-doors   body-style  drive-wheels  engine-location  ...
# 1           two  convertible           rwd            front  ...
# 2           two  convertible           rwd            front  ...
# 3           two    hatchback           rwd            front  ...
# 4          four        sedan           fwd            front  ...
#
#                   21          22        23        24           25       26  \
# ...

# %%
df=df._get_numeric_data()
df.head()
# Out:
#      0
# 0  NaN
# 1  0.0
# 2  1.0
# 3  2.0
# 4  3.0

# %%
# The KeyError occurs because the columns 'Unnamed: 0.1' and 'Unnamed: 0'
# do not exist in the DataFrame 'df' at this point.
# This is due to the preceding operation 'df=df._get_numeric_data()'
# which filtered the DataFrame to only numeric columns, leaving only column '0'.

# To fix this, we need to reload the original data to restore the column names
# before attempting to drop specific columns.
# The 'filepath' variable is available from previous cells.
df = pd.read_csv(filepath, header=0) # Assuming the first row contains headers

# Now attempt to drop the specified columns. We check for existence to prevent errors
# if one of the 'Unnamed' columns isn't actually present.
columns_to_drop = []
if 'Unnamed: 0' in df.columns:
    columns_to_drop.append('Unnamed: 0')
if 'Unnamed: 0.1' in df.columns:
    columns_to_drop.append('Unnamed: 0.1')

if columns_to_drop:
    df.drop(columns=columns_to_drop, axis=1, inplace=True)

# Let's take a look at the updated DataFrame
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
# %pip install micropip
import micropip
await micropip.install(['ipywidgets'], keep_going=True)
import ipywidgets
from ipywidgets import interact, interactive, fixed, interact_manual
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 4.2 MB/s eta 0:00:00
# ...

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    width = 12
    height = 10
    plt.figure(figsize=(width, height))

    ax1 = sns.kdeplot(RedFunction, color="r", label=RedName)
    ax2 = sns.kdeplot(BlueFunction, color="b", label=BlueName, ax=ax1)

    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of Cars')
    plt.show()
    plt.close()

# %%
def PollyPlot(xtrain, xtest, y_train, y_test, lr,poly_transform):
    width = 12
    height = 10
    plt.figure(figsize=(width, height))


    #training data
    #testing data
    # lr:  linear regression object
    #poly_transform:  polynomial transformation object

    xmax=max([xtrain.values.max(), xtest.values.max()])

    xmin=min([xtrain.values.min(), xtest.values.min()])

    x=np.arange(xmin, xmax, 0.1)


    plt.plot(xtrain, y_train, 'ro', label='Training Data')
    plt.plot(xtest, y_test, 'go', label='Test Data')
    plt.plot(x, lr.predict(poly_transform.fit_transform(x.reshape(-1, 1))), label='Predicted Function')
    plt.ylim([-10000, 60000])
    plt.ylabel('Price')
    plt.legend()

# %%
y_data = df['price']

# %%
x_data=df.drop('price',axis=1)

# %%
from sklearn.model_selection import train_test_split


x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.10, random_state=1)


print("number of test samples :", x_test.shape[0])
print("number of training samples:",x_train.shape[0])
# Out:
# number of test samples : 21
# number of training samples: 180
